# %%
# !pip install googletrans==3.1.0a0
# !pip install langdetect
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from langdetect import detect
from googletrans import Translator

# %%
# https://en.wikipedia.org/wiki/List_of_ISO_639-1_codes

languages=['Assamese', 'Bengali', 'Gujarati', 'Hindi', 'Kannada', 'Kashmiri', 'Malayalam', 'Marathi', 'Nepali', 'Oriya', 'Punjabi', 'Sanskrit', 'Sindhi', 'Tamil', 'Telugu', 'Urdu']
lang_native=['हिन्दी', 'ગુજરાતી', 'मराठी', 'বাংলা', 'ಕನ್ನಡ', 'മലയാളം', 'नेपाली', 'ଓଡ଼ିଆ', 'ਪੰਜਾਬੀ', 'தமிழ்', 'తెలుగు']
lang_iso_codes=['hi', 'gu', 'mr', 'bn', 'kn', 'ml', 'ne', 'or', 'pa', 'ta', 'te']
len(lang_iso_codes)
# Out:
# 11

# %%
def detect_and_translate(text, target_lang):
    
    result_lang = detect(text)
    # print(result_lang)
    
    if result_lang == target_lang:
        return "" 
    
    else:
        translator= Translator()
        translation = translator.translate(text, src=result_lang, dest=target_lang)
        return translation.text

# %%
json_data = {
        "language": "Change Language",

        "qbag": "Question Bank Generator",

        "qbagDescp1": "Question Bank Generator uses a crowd sourcing model to prepare question banks from a large pool of objective questions. QBaG provides an interface for paper setters and academicians to generate reliable question papers using our automated and robust system. The questions can be selected based on a range of parameters and can be exported to your desired format within minutes. Each question contributed is passed through a number of checks and is also vetted by experts.",

        "qbagDescp2": "This app is built by Team-Executables",

        "homeBanner1": "CROWDSOURCED QUESTIONS",
        "homeBanner1.2": "Get questions from various sources",
        "homeBanner1.3": "Crowdsourcing enables all the users to contribute, this helps in gathering multiple viewpoints and diversifies the archive of questions. Crowdsourcing reduces the management burden as the major work is handled by the system which frees the user from manual work",

        "homeBanner2": "RELIABLE QUESTIONS",
        "homeBanner2.2": "Verified and validated questions",
        "homeBanner2.3": "Each question contributed passes through a series of automated test, which is then scrutinised by experts",

        "homeBanner3": "EXPORT",
        "homeBanner3.2": "Export the questions in the desired format",
        "homeBanner3.3": "The selected questions can be converted into a question paper and can be exported into PDF, CSV or excel format",

        "homeBanner4": "FILTERING OPTIONS",
        "homeBanner4.2": "Choose from a variety of questions",
        "homeBanner4.3": "Filter and choose questions based on board, class, difficulty, marks, number of questions and other parameters to get the perfect list of curated questions",


        "qbagDescp3": "Create your account now, and use QBaG as your paper setter assistant.",
        "qbagDescp4": "To explore more features of QBaG, create an account to get started.",
        "footer": "Follow us on",

        "register": "Register",
        "login": "Login",
        "name": "Name",
        "employment": "Employment",
        "dragNDropProof": "Drag 'n' Drop or select a valid identity proof",
        "uploadPhotoID": "Uload Photo ID",
        "email": "Email Address",
        "userType": "User Type",
        "teacherType": "Teacher",
        "othersType": "Others",
        "schoolCollege": "School/College",
        "position": "Position",
        "education": "Education",
        "password": "Password",
        "forgotPassword": "Forgot password?",
        "dontHaveAnAccountSignUp": "Don't have an account? Sign Up",
        "alreadyHaveAnAccountSignIn": "Already have an account? Sign in",

        "addQuestion": "Add Question",
        "searchQuestion": "Search Question",
        "generateQuestionPaper": "Generate Question Paper",
        "viewPastPapers": "Generated Papers",
        "noQuestionsFound": "Sorry, No Questions Found",
        "contributeQuestions": "Contribute Questions",
        

        "questionDetails": "Question Details",
        "board": "Board",
        "langMedium": "Medium of Board",
        "grade": "Grade",
        "questionType": "Question Type",
        "mcq": "Multiple Choice Question",
        "oneWord": "One Word or Sentence",
        "fillInTheBlanks": "Fill in the Blanks",
        "matchTheFollowing": "Match the Following",
        "difficulty": "Difficulty",
        "easy": "Easy",
        "medium": "Medium",
        "hard": "Hard",
        "mark": "Mark",
        "marks": "Marks",
        "subject": "Subject",
        "typeKeywordsAndPressEnter": "Type Keywords and Press Enter",
        "question": "Question",
        "questions": "Questions",
        "numQuestions": "No. of questions",
        "key": "Key",
        "value": "Value",
        "addNew": "Add New",
        "remove": "Remove",
        "answer": "Answer",
        "answers": "Answers",
        "columnA": "Column A",
        "columnB": "Column B",
        "correctOption": "Correct Option",
        "wrongOpts": "Wrong Options",
        "wrongOption": "Type Wrong Options and Press Enter",
        "back": "Back",
        "next": "Next",

        "enterQuestion": "Enter Question",
        "addAnotherQuestion": "Add Another Question",
        "enterQuestionSuccess": "Thank you for your Question.",
        "enterQuestionError": "OOPS! a similar question already exists!",
        "search": "Search",
        "exportPDF": "Print to PDF",
        "reviewQuestion": "Review Question",
        "submitQuestion": "Submit Question",

        "invalidRegistration": "Invalid Registration Data! Please Try Again",
        "verifyEmail": "An email verification link has been sent on the given email address.\nPlease verify your email to complete the account setup.\nVerification link is valid for 24 hrs",

        "loginError1": "Invalid Login Credentials! Please Try Again",
        "loginError2": "Please validate your email! Check your inbox",

        "dashboard": "Dashboard",
        "viewIDProof": "View ID Proof",

        "changePassword": "Change Password",
        "changePasswordError": "Old password is incorrect. Please Try Again",
        "oldPassword": "Old Password",
        "newPassword": "New Password",
        "confirmNewPassword": "Confirm New Password",

        "logout": "Logout",
        "ok": "OK",
        "submit": "Submit",
        "change": "CHANGE",
        "backToHome": "Back to Home",
        "pageNotFound": "Page Not Found",

        "getResetLink": "Enter Email to Get your Password Reset Link",
        "enterNewPassword": "Enter your New Password",
        "resetPasswordAlertTitle": "Password Changed Successfully",
        "resetPasswordAlertDescription": "Your password has been reset successfully.\nPlease proceed to login",
        "resetPasswordError": "Reset Link has Expired! Please Try Again",

        "forgotPasswordError": "Invalid email ID! Please Try Again",
        "forgotPasswordAlertTitle": "Reset Password Link",
        "forgotPasswordAlertDescription": "A reset password link has been sent on the given email address.\nPlease click on the link to set your new password.\nReset link is valid for 24 hrs",

        "selectQuestions": "Select Questions",
        "selectedQuestions": "Questions Selected",
        "reviewQuestions": "Review Questions",
        "generatePaper": "Generate Paper",
        "savePaper": "Save Paper",
        "selectedQuestions": "Selected Questions",
        "easyQuestions": "No. of Easy questions",
        "mediumQuestions": "No. of Medium questions",
        "hardQuestions": "No. of Hard questions",
        "totalQuestions": "Total No. of questions",
        "totalMarks": "Total Marks",
        "mcqs": "No. of Multiple Choice Questions",
        "oneWords": "No. of One Word/Sentence Questions",
        "fillInTheBlankss": "No. Fill in the Blanks Questions",
        "matchTheFollowings": "No. Match the Following Questions",

        "paperName": "Paper Name",
        "vettedWarning": "The following questions are not vetted by the community, would you still like to continue?",
        "requested": "Requested",
        "selected": "Selected"
    }

# %%
translated_list = []
for lang in lang_iso_codes:
  print(lang)
  newData={}
  for key in json_data:
      translation = detect_and_translate(json_data[key], target_lang=lang)
      newData[key]=translation
  translated_list.append(newData)

translated_dict = dict(zip(lang_native, translated_list))
# Out:
# hi
# gu
# mr
# bn
# kn
# ml
# ne
# or
# pa
# ta
# te

# %%
translated_dict
# Out:
# {'हिन्दी': {'language': 'भाषा बदलो',
#   'qbag': 'प्रश्न बैंक जेनरेटर',
#   'qbagDescp1': 'प्रश्न बैंक जेनरेटर वस्तुनिष्ठ प्रश्नों के एक बड़े पूल से प्रश्न बैंक तैयार करने के लिए क्राउड सोर्सिंग मॉडल का उपयोग करता है। QBaG हमारे स्वचालित और मजबूत सिस्टम का उपयोग करके विश्वसनीय प्रश्न पत्र तैयार करने के लिए पेपर सेटर्स और शिक्षाविदों के लिए एक इंटरफ़ेस प्रदान करता है। प्रश्नों को कई मापदंडों के आधार पर चुना जा सकता है और मिनटों के भीतर आपके वांछित प्रारूप में निर्यात किया जा सकता है। योगदान किए गए प्रत्येक प्रश्न को कई जांचों के माध्यम से पारित किया जाता है और विशेषज्ञों द्वारा इसकी जांच भी की जाती है।',
#   'qbagDescp2': 'यह ऐप Team-Executables . द्वारा बनाया गया है',
#   'homeBanner1': 'भीड़-भाड़ वाले प्रश्न',
#   'homeBanner1.2': 'विभिन्न स्रोतों से प्रश्न प्राप्त करें',
# ...
